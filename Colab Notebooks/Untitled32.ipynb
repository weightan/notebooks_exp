# %%
from sympy import factorint
from sympy import sieve, prime
from tqdm import 
p = [i for i in sieve.primerange(1, 10**4)]
terms = [ ]

for i in p:
    terms.extend(i*k - 1 for k in range(10000))


terms = sorted(list(set(terms)))
out = []

for i in range(1, len(terms[:3000])):
    if terms[i-1]  + 1 != terms[i]:
       print(terms[i-1], terms[i])
print(out[:100])
# Out:
# -1 1
# []

# %%
a = 2**30
for i in range(12):
    print("{0:b}".format(a).rjust(24).replace("0", " "))
    b = a<<1
    c = a<<2
    a = ((~a&c)|(a&~b&~c)|(~a&b))>>1
# Out:
# 1
# 111
# 11  1
# 11 1111
# 11  1   1
# 11 1111 111
# 11  1    1  1
# 11 1111  111111
# 11  1   111     1
# 11 1111 11  1   111
# 11  1    1 1111 11  1
# 11 1111  11 1    1 1111
