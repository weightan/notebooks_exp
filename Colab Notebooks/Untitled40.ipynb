# %%
from itertools import combinations_with_replacement

terms = []
for n in range(1, 60):
    base = list(range(1, n))

    c = 0
    for i in combinations_with_replacement(base, 3):
        if sum(i) == n:
            c+=1
    terms.append(c)

print(terms)
# Out:
# [0, 0, 1, 1, 2, 3, 4, 5, 7, 8, 10, 12, 14, 16, 19, 21, 24, 27, 30, 33, 37, 40, 44, 48, 52, 56, 61, 65, 70, 75, 80, 85, 91, 96, 102, 108, 114, 120, 127, 133, 140, 147, 154, 161, 169, 176, 184, 192, 200, 208, 217, 225, 234, 243, 252, 261, 271, 280, 290]
