# %%
from math import factorial, floor 
from sympy import factorint, isprime

c = [0, 1, 1, 2, 2, 3, 2, 4, 2, 5, 3, 5, 4, 5, 5, 6, 5, 7, 5, 8, 5, 9, 6, 9, 7, 9, 8, 9, 9, 10, 10, 11, 11, 12, 11, 13, 12, 13, 13, 14, 14, 15, 14, 16, 15, 16, 16, 17, 17, 18, 18, 19, 18, 20, 19, 20, 20, 21, 21, 22, 21, 23, 22, 23, 23, 24, 24, 25, 25, 26, 25, 27]

#a(n) = a(a(n-1)) mod 2 + a(n-2) with a(0) = 0 and a(1) = 1.
terms = [0, 1]

N = 2
terms = [1, 2]
#N = 2
seq = lambda am2, am1: terms[am1 - 1]%2 + am2

for i in range(10000):
    terms.append(seq(*terms[-2:]))

print(terms)

import matplotlib.pyplot as plt
plt.plot(terms, ',')
plt.show()
plt.close()
# Out:
# [1, 2, 1, 3, 2, 3, 3, 4, 4, 5, 4, 6, 5, 6, 6, 7, 7, 8, 7, 9, 7, 10, 8, 10, 9, 10, 10, 11, 10, 12, 10, 13, 11, 13, 12, 13, 13, 14, 13, 15, 13, 16, 14, 16, 15, 16, 16, 17, 17, 18, 17, 19, 18, 19, 19, 20, 20, 21, 21, 22, 21, 23, 21, 24, 21, 25, 22, 25, 23, 25, 24, 25, 25, 26, 25, 27, 25, 28, 26, 28, 27, 28, 28, 29, 28, 30, 28, 31, 28, 32, 29, 32, 30, 32, 31, 32, 32, 33, 33, 34, 34, 35, 34, 36, 35, 36, 36, 37, 37, 38, 37, 39, 38, 39, 39, 40, 40, 41, 41, 42, 41, 43, 41, 44, 41, 45, 42, 45, 43, 45, 44, 45, 45, 46, 45, 47, 45, 48, 46, 48, 47, 48, 48, 49, 49, 50, 49, 51, 50, 51, 51, 52, 52, 53, 52, 54, 53, 54, 54, 55, 55, 56, 55, 57, 55, 58, 56, 58, 57, 58, 58, 59, 59, 60, 59, 61, 60, 61, 61, 62, 62, 63, 63, 64, 63, 65, 64, 65, 65, 66, 66, 67, 66, 68, 67, 68, 68, 69, 69, 70, 70, 71, 70, 72, 71, 72, 72, 73, 73, 74, 73, 75, 74, 75, 75, 76, 76, 77, 77, 78, 77, 79, 77, 80, 77, 81, 78, 81, 79, 81, 80, 81, 81, 82, 81, 83, 81, 84, 82, 84, 83, 84, 84, 85, 84, 86, 84, 87, 84, 88, 85, 88, 86, 88, 87, 
# ...

# %%
from sympy import isprime
from tqdm import tqdm
terms = []
for i in range(1000):
    for j in range(0, i-1):
        s = int(''.join(map(str, list(range(1, i+1)) + list(range(i-1, j, -1)))))
        #print(s)
        if isprime(s):
            print(i)
            terms.append(s)
print(sorted(terms))

# %%
terms = [1]
