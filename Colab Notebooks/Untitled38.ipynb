# %%
c = '000001111101101010101010000000111110110101010101000000011111011010101010100000001111101101010101010'
print(len(c))
s = [ c[i:i+10] for i in range(0, len(c), 10)]
print('\n'.join(s))
# Out:
# 0000011111
# 0110101010
# 1010000000
# 1111101101
# 0101010100
# 0000011111
# 0110101010
# 1010000000
# 1111101101
# 010101010

# %%
s = 'abcdefghijklmnopqrstuvwxyz'
from random import sample, choice
out = [' /' + ''.join(sample(s, choice((1,2)))) for i in range(20)]
print(''.join(out))
# Out:
#  /up /lo /c /x /is /e /an /i /p /mg /k /nj /pd /qm /jw /hi /j /ol /rt /wn
