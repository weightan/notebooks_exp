# %%
# !pip install python-lifelib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.3/725.3 KB 17.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for python-lifelib: filename=python_lifelib-2.5.6-py3-none-any.whl size=781980 sha256=c7972f5845aa838deb27370dcc6754a13827dee18c0810b42c17a4367d77a6a1
#   Stored in directory: /root/.cache/pip/wheels/82/e1/bc/b690c8f29f0fe0c6ba3303480d1bb8927ed539d1a1e66e797c
# Successfully built python-lifelib
# ...

# %%
import lifelib

sess = lifelib.load_rules("b3s23")
lt = sess.lifetree()
print(lt.pattern('yl20_1_14_c15fd3750b79948cd448835bc58e5122').rle_string().replace('\n', '').split('rule = B3/S23')[1].replace('A', 'o').replace('.', 'b'))
# Out:
# Generating code for rules ['b3s23']...
# Compiling lifelib shared object (estimated time: 20.0 seconds)...
# Estimated compilation progress:   0%|          | 0/100 [00:00<?, ?it/s]
# ...compilation complete!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-e96ff442d3b4> in <module>
#       3 sess = lifelib.load_rules("b3s23")
#       4 lt = sess.lifetree()
# ----> 5 print(lt.pattern('yl20_1_14_c15fd3750b79948cd448835bc58e5122').rle_string().replace('\n', '').split('rule = B3/S23')[1].replace('A', 'o').replace('.', 'b'))
#
# /usr/local/lib/python3.8/dist-packages/lifelib/pythlib/session.py in pattern(self, rle, rule, tempfile, verify_apgcode)
#     162
#     163         if is_apgcode and (rle[0] != 'x'):
# --> 164             raise ValueError("Only apgcodes beginning with 'x' contain sufficient information to reconstruct the pattern.")
#     165
# ...
