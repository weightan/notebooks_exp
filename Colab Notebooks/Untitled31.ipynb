# %%
from tqdm import tqdm  

first_3 = lambda n: int(str(n**3)[-6:])
difff = lambda s: [ s[i] - s[i-1]   for i in range(1, len(s))]
lessn = lambda n: all([ int(str(n)[i]) >= int(str(n)[i-1]) for i in range(1, len(str(n)))])

terms = []
t2 = []

for i in tqdm(range(2100, 80000000)):
    terms.append(first_3(i))

s =  set(terms)


for  i in s:
    if len(str(i)) == 6 and lessn(i) :
        t2.append(i)
print(t2,  len(t2))

print(len(terms), len(set(terms)))
#rint(difff(terms))

import matplotlib.pyplot as plt
plt.plot(difff(terms))
plt.ylabel('some numbers')
plt.show()
# Out:
# 100%|██████████| 79997900/79997900 [01:54<00:00, 699809.54it/s]
# ...

# %%
c = [111111, 111112, 111113, 111117, 111119, 111123, 111125, 111127, 111128, 111129, 111133, 111137, 111139, 111144, 111147, 111149, 111157, 111159, 111167, 111168, 111169, 111177, 111179, 111189, 111199, 111223, 111224, 111227, 111229, 111233, 111237, 111239, 111247, 111249, 111256, 111257, 111259, 111267, 111269, 111277, 111279, 111288, 111289, 111299, 111333, 111336, 111337, 111339, 111347, 111349, 111357, 111359, 111367, 111368, 111369, 111377, 111379, 111389, 111399, 111447, 111448, 111449, 111457, 111459, 111467, 111469, 111477, 111479, 111488, 111489, 111499, 111557, 111559, 111567, 111569, 111577, 111579, 111589, 111599, 111667, 111669, 111677, 111679, 111688, 111689, 111699, 111777, 111779, 111789, 111799, 111889, 111899, 111999, 112223, 112227, 112229, 112233, 112237, 112239, 112247, 112248, 112249, 112256, 112257, 112259, 112267, 112269, 112277, 112279, 112289, 112299, 112333, 112337, 112339, 112344, 112347, 112349, 112357, 112359, 112367, 112369, 112377, 112379, 112389, 112399, 112447, 112448, 112449, 112456, 112457, 112459, 112467, 112469, 112477, 112479, 112488, 112489, 112499, 112557, 112559, 112567, 112568, 112569, 112577, 112579, 112589, 112599, 112667, 112669, 112677, 112679, 112689, 112699, 112777, 112779, 112789, 112799, 112888, 112889, 112899, 112999, 113333, 113336, 113337, 113339, 113344, 113347, 113349, 113357, 113359, 113367, 113368, 113369, 113377, 113379, 113389, 113399, 113447, 113448, 113449, 113457, 113459, 113467, 113469, 113477, 113479, 113489, 113499, 113557, 113559, 113567, 113569, 113577, 113579, 113589, 113599, 113667, 113669, 113677, 113679, 113688, 113689, 113699, 113777, 113779, 113789, 113799, 113889, 113899, 113999, 114447, 114449, 114456, 114457, 114459, 114467, 114469, 114477, 114479, 114488, 114489, 114499, 114557, 114559, 114567, 114568, 114569, 114577, 114579, 114589, 114599, 114667, 114669, 114677, 114679, 114688, 114689, 114699, 114777, 114779, 114789, 114799, 114888, 114889, 114899, 114999, 115557, 115559, 115567, 115569, 115577, 115579, 115589, 115599, 115667, 115669, 115677, 115679, 115688, 115689, 115699, 115777, 115779, 115789, 115799, 115889, 115899, 115999, 116667, 116669, 116677, 116679, 116689, 116699, 116777, 116779, 116789, 116799, 116888, 116889, 116899, 116999, 117777, 117779, 117789, 117799, 117888, 117889, 117899, 117999, 118888, 118889, 118899, 118999, 119999, 122223, 122227, 122229, 122233, 122237, 122239, 122247, 122248, 122249, 122257, 122259, 122267, 122269, 122277, 122279, 122289, 122299, 122333, 122337, 122339, 122344, 122347, 122349, 122357, 122359, 122367, 122368, 122369, 122377, 122379, 122389, 122399, 122447, 122449, 122456, 122457, 122459, 122467, 122469, 122477, 122479, 122488, 122489, 122499, 122557, 122559, 122567, 122568, 122569, 122577, 122579, 122589, 122599, 122667, 122669, 122677, 122679, 122688, 122689, 122699, 122777, 122779, 122789, 122799, 122888, 122889, 122899, 122999, 123333, 123336, 123337, 123339, 123347, 123349, 123357, 123359, 123367, 123368, 123369, 123377, 123379, 123389, 123399, 123447, 123448, 123449, 123456, 123457, 123459, 123467, 123469, 123477, 123479, 123489, 123499, 123557, 123559, 123567, 123569, 123577, 123579, 123589, 123599, 123667, 123669, 123677, 123679, 123688, 123689, 123699, 123777, 123779, 123789, 123799, 123889, 123899, 123999, 124447, 124449, 124456, 124457, 124459, 124467, 124469, 124477, 124479, 124488, 124489, 124499, 124557, 124559, 124567, 124568, 124569, 124577, 124579, 124589, 124599, 124667, 124669, 124677, 124679, 124689, 124699, 124777, 124779, 124789, 124799, 124888, 124889, 124899, 124999, 125557, 125559, 125567, 125568, 125569, 125577, 125579, 125589, 125599, 125667, 125669, 125677, 125679, 125688, 125689, 125699, 125777, 125779, 125789, 125799, 125888, 125889, 125899, 125999, 126667, 126669, 126677, 126679, 126689, 126699, 126777, 126779, 126789, 126799, 126888, 126889, 126899, 126999, 127777, 127779, 127789, 127799, 127889, 127899, 127999, 128888, 128889, 128899, 128999, 129999, 133333, 133336, 133337, 133339, 133347, 133349, 133357, 133359, 133367, 133368, 133369, 133377, 133379, 133389, 133399, 133447, 133448, 133449, 133457, 133459, 133467, 133469, 133477, 133479, 133489, 133499, 133557, 133559, 133567, 133568, 133569, 133577, 133579, 133589, 133599, 133667, 133669, 133677, 133679, 133688, 133689, 133699, 133777, 133779, 133789, 133799, 133888, 133889, 133899, 133999, 134447, 134449, 134456, 134457, 134459, 134467, 134469, 134477, 134479, 134488, 134489, 134499, 134557, 134559, 134567, 134568, 134569, 134577, 134579, 134589, 134599, 134667, 134669, 134677, 134679, 134689, 134699, 134777, 134779, 134789, 134799, 134888, 134889, 134899, 134999, 135557, 135559, 135567, 135569, 135577, 135579, 135589, 135599, 135667, 135669, 135677, 135679, 135688, 135689, 135699, 135777, 135779, 135789, 135799, 135889, 135899, 135999, 136667, 136669, 136677, 136679, 136689, 136699, 136777, 136779, 136789, 136799, 136888, 136889, 136899, 136999, 137777, 137779, 137789, 137799, 137889, 137899, 137999, 138888, 138889, 138899, 138999, 139999, 144447, 144448, 144449, 144456, 144457, 144459, 144467, 144469, 144477, 144479, 144488, 144489, 144499, 144557, 144559, 144567, 144568, 144569, 144577, 144579, 144589, 144599, 144667, 144669, 144677, 144679, 144689, 144699, 144777, 144779, 144789, 144799, 144888, 144889, 144899, 144999, 145557, 145559, 145567, 145569, 145577, 145579, 145589, 145599, 145667, 145669, 145677, 145679, 145688, 145689, 145699, 145777, 145779, 145789, 145799, 145889, 145899, 145999, 146667, 146669, 146677, 146679, 146688, 146689, 146699, 146777, 146779, 146789, 146799, 146888, 146889, 146899, 146999, 147777, 147779, 147789, 147799, 147889, 147899, 147999, 148888, 148889, 148899, 148999, 149999, 155557, 155559, 155567, 155569, 155577, 155579, 155589, 155599, 155667, 155669, 155677, 155679, 155688, 155689, 155699, 155777, 155779, 155789, 155799, 155889, 155899, 155999, 156667, 156669, 156677, 156679, 156689, 156699, 156777, 156779, 156789, 156799, 156888, 156889, 156899, 156999, 157777, 157779, 157789, 157799, 157888, 157889, 157899, 157999, 158888, 158889, 158899, 158999, 159999, 166667, 166669, 166677, 166679, 166689, 166699, 166777, 166779, 166789, 166799, 166888, 166889, 166899, 166999, 167777, 167779, 167789, 167799, 167889, 167899, 167999, 168888, 168889, 168899, 168999, 169999, 177777, 177779, 177789, 177799, 177889, 177899, 177999, 178888, 178889, 178899, 178999, 179999, 188888, 188889, 188899, 188999, 189999, 199999, 222223, 222227, 222229, 222233, 222237, 222239, 222247, 222248, 222249, 222257, 222259, 222267, 222269, 222277, 222279, 222289, 222299, 222333, 222336, 222337, 222339, 222344, 222347, 222349, 222357, 222359, 222367, 222369, 222377, 222379, 222389, 222399, 222447, 222449, 222456, 222457, 222459, 222467, 222469, 222477, 222479, 222488, 222489, 222499, 222557, 222559, 222567, 222568, 222569, 222577, 222579, 222589, 222599, 222667, 222669, 222677, 222679, 222689, 222699, 222777, 222779, 222789, 222799, 222888, 222889, 222899, 222999, 223333, 223336, 223337, 223339, 223347, 223349, 223357, 223359, 223367, 223368, 223369, 223377, 223379, 223389, 223399, 223447, 223448, 223449, 223457, 223459, 223467, 223469, 223477, 223479, 223488, 223489, 223499, 223557, 223559, 223567, 223569, 223577, 223579, 223589, 223599, 223667, 223669, 223677, 223679, 223688, 223689, 223699, 223777, 223779, 223789, 223799, 223889, 223899, 223999, 224447, 224448, 224449, 224456, 224457, 224459, 224467, 224469, 224477, 224479, 224488, 224489, 224499, 224557, 224559, 224567, 224568, 224569, 224577, 224579, 224589, 224599, 224667, 224669, 224677, 224679, 224689, 224699, 224777, 224779, 224789, 224799, 224888, 224889, 224899, 224999, 225557, 225559, 225567, 225569, 225577, 225579, 225589, 225599, 225667, 225669, 225677, 225679, 225688, 225689, 225699, 225777, 225779, 225789, 225799, 225889, 225899, 225999, 226667, 226669, 226677, 226679, 226688, 226689, 226699, 226777, 226779, 226789, 226799, 226888, 226889, 226899, 226999, 227777, 227779, 227789, 227799, 227889, 227899, 227999, 228888, 228889, 228899, 228999, 229999, 233333, 233336, 233337, 233339, 233344, 233347, 233349, 233357, 233359, 233367, 233368, 233369, 233377, 233379, 233389, 233399, 233447, 233448, 233449, 233457, 233459, 233467, 233469, 233477, 233479, 233489, 233499, 233557, 233559, 233567, 233569, 233577, 233579, 233589, 233599, 233667, 233669, 233677, 233679, 233688, 233689, 233699, 233777, 233779, 233789, 233799, 233889, 233899, 233999, 234447, 234449, 234456, 234457, 234459, 234467, 234469, 234477, 234479, 234488, 234489, 234499, 234557, 234559, 234567, 234568, 234569, 234577, 234579, 234589, 234599, 234667, 234669, 234677, 234679, 234688, 234689, 234699, 234777, 234779, 234789, 234799, 234888, 234889, 234899, 234999, 235557, 235559, 235567, 235569, 235577, 235579, 235589, 235599, 235667, 235669, 235677, 235679, 235688, 235689, 235699, 235777, 235779, 235789, 235799, 235889, 235899, 235999, 236667, 236669, 236677, 236679, 236689, 236699, 236777, 236779, 236789, 236799, 236888, 236889, 236899, 236999, 237777, 237779, 237789, 237799, 237888, 237889, 237899, 237999, 238888, 238889, 238899, 238999, 239999, 244447, 244449, 244456, 244457, 244459, 244467, 244469, 244477, 244479, 244488, 244489, 244499, 244557, 244559, 244567, 244568, 244569, 244577, 244579, 244589, 244599, 244667, 244669, 244677, 244679, 244689, 244699, 244777, 244779, 244789, 244799, 244888, 244889, 244899, 244999, 245557, 245559, 245567, 245568, 245569, 245577, 245579, 245589, 245599, 245667, 245669, 245677, 245679, 245688, 245689, 245699, 245777, 245779, 245789, 245799, 245888, 245889, 245899, 245999, 246667, 246669, 246677, 246679, 246689, 246699, 246777, 246779, 246789, 246799, 246888, 246889, 246899, 246999, 247777, 247779, 247789, 247799, 247889, 247899, 247999, 248888, 248889, 248899, 248999, 249999, 255557, 255559, 255567, 255569, 255577, 255579, 255589, 255599, 255667, 255669, 255677, 255679, 255688, 255689, 255699, 255777, 255779, 255789, 255799, 255889, 255899, 255999, 256667, 256669, 256677, 256679, 256689, 256699, 256777, 256779, 256789, 256799, 256888, 256889, 256899, 256999, 257777, 257779, 257789, 257799, 257889, 257899, 257999, 258888, 258889, 258899, 258999, 259999, 266667, 266669, 266677, 266679, 266688, 266689, 266699, 266777, 266779, 266789, 266799, 266888, 266889, 266899, 266999, 267777, 267779, 267789, 267799, 267889, 267899, 267999, 268888, 268889, 268899, 268999, 269999, 277777, 277779, 277789, 277799, 277888, 277889, 277899, 277999, 278888, 278889, 278899, 278999, 279999, 288888, 288889, 288899, 288999, 289999, 299999, 333333, 333336, 333337, 333339, 333347, 333349, 333357, 333359, 333367, 333368, 333369, 333377, 333379, 333389, 333399, 333447, 333448, 333449, 333457, 333459, 333467, 333469, 333477, 333479, 333489, 333499, 333557, 333559, 333567, 333568, 333569, 333577, 333579, 333589, 333599, 333667, 333669, 333677, 333679, 333688, 333689, 333699, 333777, 333779, 333789, 333799, 333888, 333889, 333899, 333999, 334447, 334449, 334456, 334457, 334459, 334467, 334469, 334477, 334479, 334488, 334489, 334499, 334557, 334559, 334567, 334568, 334569, 334577, 334579, 334589, 334599, 334667, 334669, 334677, 334679, 334689, 334699, 334777, 334779, 334789, 334799, 334888, 334889, 334899, 334999, 335557, 335559, 335567, 335569, 335577, 335579, 335589, 335599, 335667, 335669, 335677, 335679, 335688, 335689, 335699, 335777, 335779, 335789, 335799, 335889, 335899, 335999, 336667, 336669, 336677, 336679, 336689, 336699, 336777, 336779, 336789, 336799, 336888, 336889, 336899, 336999, 337777, 337779, 337789, 337799, 337889, 337899, 337999, 338888, 338889, 338899, 338999, 339999, 344447, 344448, 344449, 344456, 344457, 344459, 344467, 344469, 344477, 344479, 344488, 344489, 344499, 344557, 344559, 344567, 344568, 344569, 344577, 344579, 344589, 344599, 344667, 344669, 344677, 344679, 344689, 344699, 344777, 344779, 344789, 344799, 344888, 344889, 344899, 344999, 345557, 345559, 345567, 345569, 345577, 345579, 345589, 345599, 345667, 345669, 345677, 345679, 345688, 345689, 345699, 345777, 345779, 345789, 345799, 345889, 345899, 345999, 346667, 346669, 346677, 346679, 346688, 346689, 346699, 346777, 346779, 346789, 346799, 346888, 346889, 346899, 346999, 347777, 347779, 347789, 347799, 347889, 347899, 347999, 348888, 348889, 348899, 348999, 349999, 355557, 355559, 355567, 355569, 355577, 355579, 355589, 355599, 355667, 355669, 355677, 355679, 355688, 355689, 355699, 355777, 355779, 355789, 355799, 355889, 355899, 355999, 356667, 356669, 356677, 356679, 356689, 356699, 356777, 356779, 356789, 356799, 356888, 356889, 356899, 356999, 357777, 357779, 357789, 357799, 357888, 357889, 357899, 357999, 358888, 358889, 358899, 358999, 359999, 366667, 366669, 366677, 366679, 366689, 366699, 366777, 366779, 366789, 366799, 366888, 366889, 366899, 366999, 367777, 367779, 367789, 367799, 367889, 367899, 367999, 368888, 368889, 368899, 368999, 369999, 377777, 377779, 377789, 377799, 377889, 377899, 377999, 378888, 378889, 378899, 378999, 379999, 388888, 388889, 388899, 388999, 389999, 399999, 444447, 444449, 444456, 444457, 444459, 444467, 444469, 444477, 444479, 444488, 444489, 444499, 444557, 444559, 444567, 444568, 444569, 444577, 444579, 444589, 444599, 444667, 444669, 444677, 444679, 444689, 444699, 444777, 444779, 444789, 444799, 444888, 444889, 444899, 444999, 445557, 445559, 445567, 445568, 445569, 445577, 445579, 445589, 445599, 445667, 445669, 445677, 445679, 445688, 445689, 445699, 445777, 445779, 445789, 445799, 445888, 445889, 445899, 445999, 446667, 446669, 446677, 446679, 446689, 446699, 446777, 446779, 446789, 446799, 446888, 446889, 446899, 446999, 447777, 447779, 447789, 447799, 447889, 447899, 447999, 448888, 448889, 448899, 448999, 449999, 455557, 455559, 455567, 455569, 455577, 455579, 455589, 455599, 455667, 455669, 455677, 455679, 455688, 455689, 455699, 455777, 455779, 455789, 455799, 455889, 455899, 455999, 456667, 456669, 456677, 456679, 456689, 456699, 456777, 456779, 456789, 456799, 456888, 456889, 456899, 456999, 457777, 457779, 457789, 457799, 457889, 457899, 457999, 458888, 458889, 458899, 458999, 459999, 466667, 466669, 466677, 466679, 466688, 466689, 466699, 466777, 466779, 466789, 466799, 466888, 466889, 466899, 466999, 467777, 467779, 467789, 467799, 467889, 467899, 467999, 468888, 468889, 468899, 468999, 469999, 477777, 477779, 477789, 477799, 477888, 477889, 477899, 477999, 478888, 478889, 478899, 478999, 479999, 488888, 488889, 488899, 488999, 489999, 499999, 555557, 555559, 555567, 555569, 555577, 555579, 555589, 555599, 555667, 555669, 555677, 555679, 555688, 555689, 555699, 555777, 555779, 555789, 555799, 555889, 555899, 555999, 556667, 556669, 556677, 556679, 556689, 556699, 556777, 556779, 556789, 556799, 556888, 556889, 556899, 556999, 557777, 557779, 557789, 557799, 557888, 557889, 557899, 557999, 558888, 558889, 558899, 558999, 559999, 566667, 566669, 566677, 566679, 566689, 566699, 566777, 566779, 566789, 566799, 566888, 566889, 566899, 566999, 567777, 567779, 567789, 567799, 567889, 567899, 567999, 568888, 568889, 568899, 568999, 569999, 577777, 577779, 577789, 577799, 577889, 577899, 577999, 578888, 578889, 578899, 578999, 579999, 588888, 588889, 588899, 588999, 589999, 599999, 666667, 666669, 666677, 666679, 666688, 666689, 666699, 666777, 666779, 666789, 666799, 666888, 666889, 666899, 666999, 667777, 667779, 667789, 667799, 667889, 667899, 667999, 668888, 668889, 668899, 668999, 669999, 677777, 677779, 677789, 677799, 677888, 677889, 677899, 677999, 678888, 678889, 678899, 678999, 679999, 688888, 688889, 688899, 688999, 689999, 699999, 777777, 777779, 777789, 777799, 777889, 777899, 777999, 778888, 778889, 778899, 778999, 779999, 788888, 788889, 788899, 788999, 789999, 799999, 888888, 888889, 888899, 888999, 889999, 899999, 999999] 

c = set([i for i in c  ])
t = set()

for  i in range(10**6):

    if (i**3)%(10**7) in c:
        t.add(i)

print(len(t))
print(t)
# Out:
# 303
# ...

# %%
c = [229889, 648199, 29192, 688649, 892432, 500753, 116242, 960529, 18453, 125462, 401942, 45592, 721942, 859159, 269853, 851999, 416289, 444964, 326693, 127529, 998442, 866859, 229932, 189999, 238639, 439859, 784949, 332342, 374842, 506942, 39999, 698942, 147523, 571459, 822853, 774214, 729159, 847429, 982599, 116299, 214092, 239693, 839759, 90192, 218192, 803922, 317523, 860753, 31829, 175192, 495192, 59999, 152159, 181859, 847459, 457829, 291942, 831592, 664682, 458859, 825453, 229999, 286832, 741999, 944753, 856692, 447093, 655989, 212599, 651899, 941692, 228989, 546429, 79999, 745599, 940672, 288899, 861829, 277645, 76942, 279693, 157329, 764574, 99999, 314529, 668322, 673442, 731299, 305829, 661499, 267432, 389289, 551592, 911529, 427692, 512172, 7342, 518829, 592046, 100529, 356529, 781999, 512692, 117429, 801459, 962742, 276153, 532153, 917692, 119999, 396992, 130753, 230082, 264386, 553153, 608963, 852159, 547529, 631499, 181453, 489682, 379092, 549589, 876759, 448736, 239842, 501989, 689386, 26859, 216299, 817899, 904429, 191729, 563442, 863477, 518393, 194299, 66299, 221949, 164093, 159999, 206592, 932092, 535299, 889092, 454919, 318729, 784649, 831242, 231692, 677645, 777999, 850192, 579859, 316692, 435989, 315672, 58649, 78617, 342299, 348442, 406296, 598299, 488223, 582432, 192289, 574753, 711963, 766242, 845599, 155942, 31529, 951082, 528172, 214829, 716592, 803636, 786233, 881949, 155453, 199999, 711999, 699386, 688453, 567623, 973129, 200523, 69453, 143182, 49999, 75599, 739153, 292692, 379732, 558932, 843092, 258393, 370523, 377692, 174429, 505692, 754529, 870753, 325989, 536422, 199529, 238442, 302442, 568172, 731499, 305519, 654192, 540529, 259442, 918899, 941942, 375159, 716153, 843129, 972153, 751999, 622464, 670592, 987529, 21899, 89999, 23442, 307092, 854932, 121753, 441242, 806299, 264092, 344989, 681886, 79263, 259999, 575393, 75682, 707999, 726942, 618919, 225192, 549289, 713129, 882599, 670129, 839092, 571829, 668599, 715192, 843192, 128442, 442299, 621499, 937919, 800192, 699842, 424899, 485829, 831942, 91592, 385992, 567753, 166859, 178636, 21453, 660429, 129999, 596432, 695242, 274386, 984529, 15829, 592853, 911832, 288729, 168922, 583129, 228829, 346589, 299999, 540129, 809442, 707046, 18919, 29159, 349159, 471529, 218092, 616942, 149999, 175599, 625649, 269299, 617459, 719859, 909299, 937753, 504314, 187899, 504829, 601599]

from tqdm import tqdm 

c = sorted(c)

# print(len(c))
# print(c)
maxk = 0

for i in tqdm(range(13015521, 100000000)):
    for n in c:
        k  = str((i*(10**6)  + n)**3 )
        
        for i in range(1, len(k)):
            if int(k[i-1]) > int(k[i]):
                break
        else:
            print(k)
            break
             
        if  len(k) > maxk:
            print(len(k))
            maxk = len(k)
# Out:
#   0%|          | 128/86984479 [00:00<18:59:53, 1271.81it/s]
# 40
#   0%|          | 369981/86984479 [05:33<21:41:43, 1108.97it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-fd00f81b4a31> in <module>()
#      11 for i in tqdm(range(13015521, 100000000)):
#      12     for n in c:
# ---> 13         k  = str((i*(10**6)  + n)**3 )
#      14
#      15         for i in range(1, len(k)):
#
# KeyboardInterrupt:

# %%
from tqdm import tqdm 


def step(s, n = 0):

    if n == N:
        out.add(s)
        return
    if len(s) == 0:
        for i in range(1, 10):
            step(s + str(i), n+1)
    else:
        for i in range(int(s[-1]), 10):
            step(s + str(i), n+1)

N = 9
out = set()

step('')
out = [ int(i) for i in sorted(list(out)) ] 
print(len(out))
t = set()

# for i in tqdm(range(1, 10**(N+1))):
#     if (i**3)%(10**(N+1)) in out:
#         t.add(i)
# Out:
# 24310

# %%
minam = 1

for m in range(4, 100000000):
    m = 10**m
    s = set()
    for i in range(0, m+1):
        s.add((i**3) % m)

    if minam > len(s)/m:
        minam  = len(s)/m
        print('m: ',  m, 'len s: ', len(s),minam)
        #print(m)
# Out:
# m:  10000 len s:  5050 0.505
# m:  100000 len s:  47899 0.47899
# m:  1000000 len s:  466237 0.466237
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-bc3b7b59e0fb> in <module>()
#       5     s = set()
#       6     for i in range(0, m+1):
# ----> 7         s.add((i**3) % m)
#       8
#       9     if minam > len(s)/m:
#
# KeyboardInterrupt:

# %%
def step(s, n = 0):

    if n == N:
        out.add(s)
        return
    if len(s) == 0:
        for i in range(1, 10):
            step(s + str(i), n+1)
    else:
        for i in range(int(s[-1]), 10):
            step(s + str(i), n+1)

N = 14
out = set()

step('')
out = [ int(i) for i in sorted(list(out)) ] 


mm = 1000000               

s = set()
for i in range(0, mm+1):
    s.add((i**3) % mm)

terms = set()

for i in out:
    r = i % mm
    if r  in s:
        terms.add( r )

print(len(terms))
print([ i for i in sorted(terms) if len(set(str(i))) == 1 ]   )
# Out:
# 1976
# [111111, 333333, 777777, 888888, 999999]

# %%
pi = 71

for p  in  range(3, 1000):
    # p =  6

    n  = 10**p
    
    for i in range(1, 10):
        if (int(str(i) + str(pi))**3)%n  == int('1'* (p)):
            print(p,  int(str(i) + str(pi)),  int(str(i) + str(pi))**3)
            pi = int(str(i) + str(pi))
            break
print(list(map(int, list(str(pi))[::-1])))
# Out:
# 3 471 104487111
# 4 8471 607860671111
# 5 88471 692472942511111
# 6 288471 24005263647111111
# 7 8288471 569407609691831111111
# 8 68288471 318450669682903211111111
# 9 368288471 49953321584048960111111111
# 10 7368288471 400036722913885923621111111111
# 11 37368288471 52180666343882322529311111111111
# 12 637368288471 258923432384877251054643111111111111
# 13 6637368288471 292406988619925010938375781111111111111
# 14 16637368288471 4605257209065238567083911011111111111111
# 15 716637368288471 368042820890750498187497271377111111111111111
# 16 8716637368288471 662288076355335397389032413699561111111111111111
# 17 58716637368288471 202434033390055312140456813141375711111111111111111
# 18 858716637368288471 633212722189717735780029541304784194111111111111111111
# 19 9858716637368288471 958211000711597533567643781741835765901111111111111111111
# 20 79858716637368288471 509292147254569119612816584076634854512511111111111111111111
# ...
