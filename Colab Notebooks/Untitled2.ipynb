# %%
from sympy import divisors, prod, primefactors
from itertools import combinations
n = 441
d = [i for i in divisors(n) if i%4 == 1 and i not in (1,n)]
pairs = [(primefactors(i[0]), primefactors(i[1]))  for i in combinations(d, 2) if prod(i) == n]
print(d)
# Out:
# [9, 21, 49]

# %%
from math import floor, factorial
wilson_f = lambda n: 2 + (2*factorial(n) % (n+1))

print(wilson_f(10**7 + 2))
# Out:
# 2
