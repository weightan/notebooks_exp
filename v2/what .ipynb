# %%
from random import random, choice

arr = [1,2,3,4,5,6]
f = 1
pred = [1,1,1,2,3,4,3,6]

def gen_str_r(t):
    arr.remove(f)
    
    return [f if random()< 0.5 else choice(arr) for i in range(t)]

def split(arr, f):
    arr.remove(f)
    arr.extend([f]*(5 ))
    return arr

def prob_arr(arr):
    out = dict()
    for i in set(arr):
        out[i] = f'{arr.count(i)}/{len(arr)}'
    return(out)

def apply_s(s, n):
    for i in range(n):
        s = split(s, choice(arr))
    return s

s = apply_s(arr, 1000)

print(prob_arr(s))
# Out:
# {1: '81/4006', 2: '9/4006', 3: '9/4006', 4: '201/4006', 5: '1/4006', 6: '3705/4006'}
