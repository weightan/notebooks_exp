# %%
from itertools import product
n = 4
k = 4
n_of_diff_t = n-1

is_right=lambda it:all(len(set(it[st+t] for t in range(n))) == n_of_diff_t for st in range(0,len(it)-n+1)) 
for i in range(0,20):
    c = 0
    terms = []
    for p in product(list(range(k)), repeat=i):
        if is_right(p):
            c+=1
            #terms.append(p)

    print(c)
# Out:
# 1
# 4
# 16
# 64
# 144
# 360
# 888
# 2184
# 5400
# 13320
# 32856
# 81096
# 200088
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-ad3de3ac7f6f> in <module>()
#       9     terms = []
#      10     for p in product(list(range(k)), repeat=i):
# ---> 11         if is_right(p):
#      12             c+=1
#      13             #terms.append(p)
#
# <ipython-input-49-ad3de3ac7f6f> in <lambda>(it)
#       4 n_of_diff_t = n-1
#       5
# ----> 6 is_right=lambda it:all(len(set(it[st+t] for t in range(n))) == n_of_diff_t for st in range(0,len(it)-n+1))
#       7 for i in range(0,20):
#       8     c = 0
#
# <ipython-input-49-ad3de3ac7f6f> in <genexpr>(.0)
#       4 n_of_diff_t = n-1
#       5
# ----> 6 is_right=lambda it:all(len(set(it[st+t] for t in range(n))) == n_of_diff_t for st in range(0,len(it)-n+1))
#       7 for i in range(0,20):
#       8     c = 0
#
# ...

# %%
is_right((1,1,))
# Out:
# True
